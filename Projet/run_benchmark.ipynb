# %% [markdown]
# # Orchestrateur
#
# Ce notebook gère l'exécution des benchmarks pour tous les agents.
#
# **Processus :**
# 1.  Définit la liste de tous les agents à tester.
# 2.  Pour chaque agent, il appelle votre script `RunAgents.py` en utilisant `subprocess`.
# 3.  Il capture la sortie (stdout) et les erreurs (stderr) de chaque script.
# 4.  Il mesure le temps total d'exécution pour chaque agent.
#
# **Important :** Vous devez avoir un script nommé `RunAgents.py` dans le même dossier que ce notebook pour que cela fonctionne.
#
# Une fois ce notebook terminé, vous pouvez ouvrir `Report.ipynb` pour analyser les résultats.

# %% [markdown]
# ## 1. Configuration des Agents
#
# Liste des noms de classe des agents (doit correspondre aux noms de fichiers `.py` dans le dossier `agents/`).

# %%
agent_files_to_run = [
    'BestAgentMLP',
    'ExtraTreeAgent5features',
    'ExtraTreeAgent9features',
    'KNNFaiss',
    'LGBEXTHybride',
    'LGBMAgent5features',
    'MLPAgentBase',
    'MLPBoost10features',
    'MLPV2_1'
    
]
"""
Voici une liste plus large d'autres agents que vous pouvez lancer : 





"""
print(f"{len(agent_files_to_run)} agents sont configurés pour le test.")
# Out:
# 9 agents sont configurés pour le test.

# %% [markdown]
# ## 2. Boucle d'Exécution
#
# Cette cellule exécute le script `RunAgents.py` pour chaque agent de la liste. Contrairement aux tests qu'on a utilisé pour selectionner nos agents, ici on affichera uniquement la première tache pour un soucis de lisibilité et de temps.
#
# Les scripts des agents sont donnés dans le dossier `agents` si vous souhaitez les essayer.

# %%
import subprocess
import time
import sys
import os

print("DÉBUT DU BENCHMARK GLOBAL\n" + "="*70)
overall_start_time = time.time()
total_agents = len(agent_files_to_run)

for i, agent_name in enumerate(agent_files_to_run):
    print(f"\n--- [Agent {i+1}/{total_agents}] Lancement de : {agent_name} ---")
    agent_start_time = time.time()
    
    # Utilise 'sys.executable' pour s'assurer d'utiliser le même interpréteur python
    # AJOUT DE -X utf8 pour forcer l'encodage
    command = [sys.executable, '-X', 'utf8', 'RunAgents.py', agent_name]
    
    # On récupère l'environnement actuel et on force l'encodage pour python
    env = os.environ.copy()
    env['PYTHONIOENCODING'] = 'utf-8'

    try:
        # Exécute le script en tant que sous-processus
        # On capture en bytes (capture_output=True) puis on décode manuellement
        result = subprocess.run(command, 
                                capture_output=True, 
                                env=env, 
                                timeout=600 # Ajout d'un timeout de 10min au cas où
                               )
        
        # Décodage manuel en remplaçant les erreurs
        stdout_str = result.stdout.decode('utf-8', errors='replace')
        stderr_str = result.stderr.decode('utf-8', errors='replace')
        
    except Exception as e:
        print(f"!!! ERREUR SYSTÈME (subprocess) pour {agent_name} : {e} !!!")
        print(f"--- [Agent {i+1}/{total_agents}] {agent_name} ÉCHOUÉ (Erreur Subprocess) ---")
        continue 

    agent_elapsed_time = time.time() - agent_start_time
    
    # --- Afficher les résultats ---
    print("--- STDOUT  ---")
    print(stdout_str)
    
    if result.returncode == 0:
        # Succès
        if stderr_str: # Afficher les warningv s'il y'en a 
            print("--- STDERR  ---")
            print(stderr_str)
        print(f"--- [Agent {i+1}/{total_agents}] {agent_name} TERMINÉ en {agent_elapsed_time:.2f}s ---")
    else:
        print(f"!!! ERREUR D'EXÉCUTION pour {agent_name} (Code de retour: {result.returncode}) !!!")
        print("--- STDERR  ---")
        print(stderr_str)
        print(f"--- [Agent {i+1}/{total_agents}] {agent_name} ÉCHOUÉ en {agent_elapsed_time:.2f}s ---")

overall_elapsed_time = time.time() - overall_start_time
print("\n" + "="*70)
print(f"BENCHMARK GLOBAL TERMINÉ.")
print(f"Temps total d'exécution : {overall_elapsed_time:.2f} secondes")
print("Vous pouvez maintenant ouvrir 'Report.ipynb' pour analyser les résultats.")
# Out:
# DÉBUT DU BENCHMARK GLOBAL
# ======================================================================
#
# --- [Agent 1/9] Lancement de : BestAgentMLP ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : BestAgentMLP
#
# ============================================================
# ÉVALUATION DE L'AGENT : BestAgentMLP
# ============================================================
#
# --- Tâche 1/7 ---
# Tâche 1: Précision = 98.56%, Temps = 54.0587s, CPU = 87.4062s
# --- Tâche 2/7 ---
# Tâche 2: Précision = 98.67%, Temps = 53.5235s, CPU = 87.5938s
# --- Tâche 3/7 ---
# Tâche 3: Précision = 98.49%, Temps = 52.7704s, CPU = 85.9062s
# --- Tâche 4/7 ---
# Tâche 4: Précision = 98.62%, Temps = 51.4188s, CPU = 84.2344s
# --- Tâche 5/7 ---
# Tâche 5: Précision = 98.62%, Temps = 53.7507s, CPU = 86.8438s
# --- Tâche 6/7 ---
# Tâche 6: Précision = 98.57%, Temps = 52.7397s, CPU = 84.7500s
# --- Tâche 7/7 ---
# Tâche 7: Précision = 98.56%, Temps = 52.8016s, CPU = 84.7188s
#
# Résultats sauvegardés dans : soumissions\BestAgentMLP_results.json
#
# Résumé pour BestAgentMLP:
#   Précision moyenne: 98.58% ± 0.05%
#   Temps total (réel): 371.06s
#   Temps total (CPU) : 601.45s
#   Pic de RAM          : 1016.64 MB
#
# --- [Agent 1/9] BestAgentMLP TERMINÉ en 376.07s ---
#
# --- [Agent 2/9] Lancement de : ExtraTreeAgent5features ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : ExtraTreeAgent5features
#
# ============================================================
# ÉVALUATION DE L'AGENT : ExtraTreeAgent5features
# ============================================================
#
# --- Tâche 1/7 ---
# Tâche 1: Précision = 97.27%, Temps = 29.9647s, CPU = 57.7344s
# --- Tâche 2/7 ---
# Tâche 2: Précision = 97.34%, Temps = 31.2011s, CPU = 60.6094s
# --- Tâche 3/7 ---
# Tâche 3: Précision = 97.22%, Temps = 31.4502s, CPU = 61.5000s
# --- Tâche 4/7 ---
# Tâche 4: Précision = 97.23%, Temps = 32.3663s, CPU = 63.4219s
# --- Tâche 5/7 ---
# Tâche 5: Précision = 97.24%, Temps = 31.9727s, CPU = 62.5156s
# --- Tâche 6/7 ---
# Tâche 6: Précision = 97.25%, Temps = 31.8412s, CPU = 62.1875s
# --- Tâche 7/7 ---
# Tâche 7: Précision = 97.27%, Temps = 32.3416s, CPU = 62.5000s
#
# Résultats sauvegardés dans : soumissions\ExtraTreeAgent5features_results.json
#
# Résumé pour ExtraTreeAgent5features:
#   Précision moyenne: 97.26% ± 0.04%
#   Temps total (réel): 221.14s
#   Temps total (CPU) : 430.47s
#   Pic de RAM          : 604.15 MB
#
# --- [Agent 2/9] ExtraTreeAgent5features TERMINÉ en 224.20s ---
#
# --- [Agent 3/9] Lancement de : ExtraTreeAgent9features ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : ExtraTreeAgent9features
#
# ============================================================
# ÉVALUATION DE L'AGENT : ExtraTreeAgent9features
# ============================================================
#
# --- Tâche 1/7 ---
# Tâche 1: Précision = 97.27%, Temps = 34.3148s, CPU = 63.7188s
# --- Tâche 2/7 ---
# Tâche 2: Précision = 97.22%, Temps = 34.2748s, CPU = 64.1875s
# --- Tâche 3/7 ---
# Tâche 3: Précision = 97.20%, Temps = 34.6685s, CPU = 64.6094s
# --- Tâche 4/7 ---
# Tâche 4: Précision = 97.31%, Temps = 34.2159s, CPU = 63.9531s
# --- Tâche 5/7 ---
# Tâche 5: Précision = 97.20%, Temps = 34.1719s, CPU = 64.2031s
# --- Tâche 6/7 ---
# Tâche 6: Précision = 97.16%, Temps = 34.5610s, CPU = 64.4219s
# --- Tâche 7/7 ---
# Tâche 7: Précision = 97.30%, Temps = 35.9018s, CPU = 67.3281s
#
# Résultats sauvegardés dans : soumissions\ExtraTreeAgent9features_results.json
#
# Résumé pour ExtraTreeAgent9features:
#   Précision moyenne: 97.24% ± 0.05%
#   Temps total (réel): 242.11s
#   Temps total (CPU) : 452.42s
#   Pic de RAM          : 1538.07 MB
#
# --- [Agent 3/9] ExtraTreeAgent9features TERMINÉ en 245.31s ---
#
# --- [Agent 4/9] Lancement de : KNNFaiss ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : KNNFaiss
#
# ============================================================
# ÉVALUATION DE L'AGENT : KNNFaiss
# ============================================================
#
# --- Tâche 1/7 ---
# Tâche 1: Précision = 27.09%, Temps = 1.4591s, CPU = 2.3906s
# --- Tâche 2/7 ---
# Tâche 2: Précision = 26.79%, Temps = 1.5708s, CPU = 2.6094s
# --- Tâche 3/7 ---
# Tâche 3: Précision = 27.03%, Temps = 1.5827s, CPU = 2.6094s
# --- Tâche 4/7 ---
# Tâche 4: Précision = 27.53%, Temps = 1.5787s, CPU = 2.6250s
# --- Tâche 5/7 ---
# Tâche 5: Précision = 27.18%, Temps = 1.4920s, CPU = 2.4531s
# --- Tâche 6/7 ---
# Tâche 6: Précision = 27.29%, Temps = 1.4275s, CPU = 2.3438s
# --- Tâche 7/7 ---
# Tâche 7: Précision = 27.34%, Temps = 1.4400s, CPU = 2.3594s
#
# Résultats sauvegardés dans : soumissions\KNNFaiss_results.json
#
# Résumé pour KNNFaiss:
#   Précision moyenne: 27.18% ± 0.22%
#   Temps total (réel): 10.55s
#   Temps total (CPU) : 17.39s
#   Pic de RAM          : 413.24 MB
#
# --- [Agent 4/9] KNNFaiss TERMINÉ en 13.53s ---
#
# --- [Agent 5/9] Lancement de : LGBEXTHybride ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : LGBEXTHybride
#
# ============================================================
# ÉVALUATION DE L'AGENT : LGBEXTHybride
# ============================================================
#
# --- Tâche 1/7 ---
# Tâche 1: Précision = 96.90%, Temps = 81.7697s, CPU = 160.8750s
# --- Tâche 2/7 ---
# Tâche 2: Précision = 96.78%, Temps = 82.1550s, CPU = 161.2188s
# --- Tâche 3/7 ---
# Tâche 3: Précision = 96.98%, Temps = 82.6281s, CPU = 162.6250s
# --- Tâche 4/7 ---
# Tâche 4: Précision = 96.85%, Temps = 78.5899s, CPU = 155.6719s
# --- Tâche 5/7 ---
# Tâche 5: Précision = 96.94%, Temps = 76.0513s, CPU = 150.4688s
# --- Tâche 6/7 ---
# Tâche 6: Précision = 96.81%, Temps = 81.2659s, CPU = 160.4844s
# --- Tâche 7/7 ---
# Tâche 7: Précision = 96.89%, Temps = 82.8017s, CPU = 163.2500s
#
# Résultats sauvegardés dans : soumissions\LGBEXTHybride_results.json
#
# Résumé pour LGBEXTHybride:
#   Précision moyenne: 96.88% ± 0.07%
#   Temps total (réel): 565.26s
#   Temps total (CPU) : 1114.59s
#   Pic de RAM          : 288.44 MB
#
# --- STDERR  ---
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\ayoub\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#
# --- [Agent 5/9] LGBEXTHybride TERMINÉ en 568.53s ---
#
# --- [Agent 6/9] Lancement de : LGBMAgent5features ---
# !!! ERREUR SYSTÈME (subprocess) pour LGBMAgent5features : Command '['C:\\Users\\ayoub\\AppData\\Local\\Programs\\Python\\Python313\\python.exe', '-X', 'utf8', 'RunAgents.py', 'LGBMAgent5features']' timed out after 600 seconds !!!
# --- [Agent 6/9] LGBMAgent5features ÉCHOUÉ (Erreur Subprocess) ---
#
# --- [Agent 7/9] Lancement de : MLPAgentBase ---
# !!! ERREUR SYSTÈME (subprocess) pour MLPAgentBase : Command '['C:\\Users\\ayoub\\AppData\\Local\\Programs\\Python\\Python313\\python.exe', '-X', 'utf8', 'RunAgents.py', 'MLPAgentBase']' timed out after 600 seconds !!!
# --- [Agent 7/9] MLPAgentBase ÉCHOUÉ (Erreur Subprocess) ---
#
# --- [Agent 8/9] Lancement de : MLPBoost10features ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : MLPBoost10features
#
# ============================================================
# ÉVALUATION DE L'AGENT : MLPBoost10features
# ============================================================
#
#
# --- STDERR  ---
# Problème avec l'agent 'MLPBoost10features': Impossible d'importer le fichier 'agents.MLPBoost10features'. Vérifiez le nom du fichier et s'il contient des erreurs. (No module named 'agents.MLPBoost10features')
#
# --- [Agent 8/9] MLPBoost10features TERMINÉ en 0.15s ---
#
# --- [Agent 9/9] Lancement de : MLPV2_1 ---
# --- STDOUT  ---
# Mode 1: Exécution d'un seul agent : MLPV2_1
#
# ============================================================
# ÉVALUATION DE L'AGENT : MLPV2_1
# ============================================================
#
#
# --- STDERR  ---
# Problème avec l'agent 'MLPV2_1': Impossible d'importer le fichier 'agents.MLPV2_1'. Vérifiez le nom du fichier et s'il contient des erreurs. (No module named 'agents.MLPV2_1')
#
# --- [Agent 9/9] MLPV2_1 TERMINÉ en 0.19s ---
#
# ======================================================================
# BENCHMARK GLOBAL TERMINÉ.
# Temps total d'exécution : 2628.12 secondes
# Vous pouvez maintenant ouvrir 'Report.ipynb' pour analyser les résultats.
